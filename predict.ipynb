# %%
import requests

# url = "Provide your url here"

years_list = [1, 3, 5, 7, 10]

for years in years_list:
    response = requests.post(
        url,
        json={"years_experience": years}
    )
    
    result = response.json()
    print(years, "years experience salary =", result["predicted_salary"])
# Out:
# 1 years experience salary = 32874.30314220471
# 3 years experience salary = 41964.50324105758
# 5 years experience salary = 51054.703339910455
# 7 years experience salary = 60144.90343876332
# 10 years experience salary = 73780.20358704263
